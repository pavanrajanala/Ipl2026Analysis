# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanrajanala/Ipl2026Analysis/blob/main/Ipl2026Analysis_DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8fd3436c-eeef-44aa-bf84-281f8bcc0949" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8fd3436c-eeef-44aa-bf84-281f8bcc0949">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
matches = pd.read_csv('matches.csv')
batting_stats = pd.read_csv('batting_stats.csv')
bowling_stats = pd.read_csv('bowling_stats.csv')
delivery = pd.read_csv('deliveries.csv')
points_table=pd.read_csv('points_table.csv')
# Out:
# /tmp/ipykernel_7338/3018486482.py:4: DtypeWarning: Columns (19) have mixed types. Specify dtype option on import or set low_memory=False.
#   delivery = pd.read_csv('deliveries.csv')

# %%
matches.head()
batting_stats.head()
bowling_stats.head()
delivery.head()
points_table.head()
# Out:
#    pos                         team  played  won  lost  no_result  points
# 0    1  Royal Challengers Bengaluru      16   11     5          0      22
# 1    2               Gujarat Titans      17   10     7          0      20
# 2    3             Rajasthan Royals      16    9     7          0      18
# 3    4          Sunrisers Hyderabad      15    9     6          0      18
# 4    5                 Punjab Kings      14    7     6          1      15

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=points_table)
# Out:
# https://docs.google.com/spreadsheets/d/1kElxGaXiAc6gqKo04GOsFWxGWH9ENTq5eF9CH_rtjcE/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1kElxGaXiAc6gqKo04GOsFWxGWH9ENTq5eF9CH_rtjcE/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
matches.head()
# Out:
#    season        date  match_id  \
# 0    2026  2026/03/28   1527674
# 1    2026  2026/03/29   1527675
# 2    2026  2026/03/30   1527676
# 3    2026  2026/03/31   1527677
# 4    2026  2026/04/01   1527678
#
#                                                venue            city  \
# 0                   M Chinnaswamy Stadium, Bengaluru       Bengaluru
# 1                           Wankhede Stadium, Mumbai          Mumbai
# 2                Barsapara Cricket Stadium, Guwahati        Guwahati
# 3  Maharaja Yadavindra Singh International Cricke...  New Chandigarh
# 4  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...         Lucknow
#
#                    toss_winner toss_decision player_of_match  \
# 0  Royal Challengers Bengaluru         field        JA Duffy
# 1               Mumbai Indians         field       SN Thakur
# 2             Rajasthan Royals         field        N Burger
# 3                 Punjab Kings         field      C Connolly
# ...

# %%
batting_stats.head()
# Out:
#             batter                 batting_team  innings    runs  balls_faced  \
# 0    V Suryavanshi             Rajasthan Royals       16  1552.0          688
# 1     Shubman Gill               Gujarat Titans       16  1464.0          944
# 2  B Sai Sudharsan               Gujarat Titans       17  1444.0          962
# 3          V Kohli  Royal Challengers Bengaluru       16  1350.0          850
# 4        H Klaasen          Sunrisers Hyderabad       15  1248.0          826
#
#    fours  sixes  dismissals  highest    avg      sr  50s  100s
# 0    126    144          32    206.0  48.50  225.58    6     6
# 1    148     66          32    208.0  45.75  155.08    4     7
# 2    150     60          32    200.0  45.12  150.10    0     9
# 3    146     50          24    210.0  56.25  158.82    5     6
# 4     96     62          26    138.0  48.00  151.09    6     6

# %%
bowling_stats.head()
# Out:
#         bowler  matches  balls  runs_given  wickets  overs  economy    avg  \
# 0     K Rabada       17    800      1262.0       58  133.2     9.46  21.76
# 1      B Kumar       16    782      1008.0       56  130.2     7.73  18.00
# 2    JC Archer       16    758      1132.0       50  126.2     8.96  22.64
# 3     A Kamboj       14    630      1070.0       42  105.0    10.19  25.48
# 4  Rashid Khan       17    696      1054.0       42  116.0     9.09  25.10
#
#       sr
# 0  13.79
# 1  13.96
# 2  15.16
# 3  15.00
# 4  16.57

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=bowling_stats)
# Out:
# https://docs.google.com/spreadsheets/d/18TTvaWRDuVxNX85jOGcnobChCMdp9RaUehjWUHN5hv4/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/18TTvaWRDuVxNX85jOGcnobChCMdp9RaUehjWUHN5hv4/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
delivery.head()
# Out:
#    match_id  season        date                             venue  inning  \
# 0   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
# 1   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
# 2   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
# 3   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
# 4   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
#
#    over_ball  over_ball2         batting_team                 bowling_team  \
# 0        0.1         0.1  Sunrisers Hyderabad  Royal Challengers Bengaluru
# 1        0.2         0.2  Sunrisers Hyderabad  Royal Challengers Bengaluru
# 2        0.3         0.3  Sunrisers Hyderabad  Royal Challengers Bengaluru
# 3        0.4         0.4  Sunrisers Hyderabad  Royal Challengers Bengaluru
# 4        0.5         0.5  Sunrisers Hyderabad  Royal Challengers Bengaluru
#
# ...
