# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanrajanala/Ipl2026Analysis/blob/main/Ipl2026Analysis_DataCleaning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c015412d-d73d-4e7c-b2ac-a304183af9a3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c015412d-d73d-4e7c-b2ac-a304183af9a3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
matches = pd.read_csv('matches.csv')
batting_stats = pd.read_csv('batting_stats.csv')
bowling_stats = pd.read_csv('bowling_stats.csv')
delivery = pd.read_csv('deliveries.csv',low_memory=False)
points_table=pd.read_csv('points_table.csv')

# %%
matches.head()
batting_stats.head()
bowling_stats.head()
delivery.head()
points_table.head()
# Out:
#    pos                         team  played  won  lost  no_result  points
# 0    1  Royal Challengers Bengaluru      16   11     5          0      22
# 1    2               Gujarat Titans      17   10     7          0      20
# 2    3             Rajasthan Royals      16    9     7          0      18
# 3    4          Sunrisers Hyderabad      15    9     6          0      18
# 4    5                 Punjab Kings      14    7     6          1      15

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=points_table)
# Out:
# https://docs.google.com/spreadsheets/d/1YVPOZOqCinzrWJQYgUbBELozwXVfVjqak5TjhbnDAW8/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1YVPOZOqCinzrWJQYgUbBELozwXVfVjqak5TjhbnDAW8/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
matches.head()
# Out:
#    season        date  match_id  \
# 0    2026  2026/03/28   1527674
# 1    2026  2026/03/29   1527675
# 2    2026  2026/03/30   1527676
# 3    2026  2026/03/31   1527677
# 4    2026  2026/04/01   1527678
#
#                                                venue            city  \
# 0                   M Chinnaswamy Stadium, Bengaluru       Bengaluru
# 1                           Wankhede Stadium, Mumbai          Mumbai
# 2                Barsapara Cricket Stadium, Guwahati        Guwahati
# 3  Maharaja Yadavindra Singh International Cricke...  New Chandigarh
# 4  Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...         Lucknow
#
#                    toss_winner toss_decision player_of_match  \
# 0  Royal Challengers Bengaluru         field        JA Duffy
# 1               Mumbai Indians         field       SN Thakur
# 2             Rajasthan Royals         field        N Burger
# 3                 Punjab Kings         field      C Connolly
# ...

# %%
batting_stats.head()
# Out:
#             batter                 batting_team  innings    runs  balls_faced  \
# 0    V Suryavanshi             Rajasthan Royals       16  1552.0          688
# 1     Shubman Gill               Gujarat Titans       16  1464.0          944
# 2  B Sai Sudharsan               Gujarat Titans       17  1444.0          962
# 3          V Kohli  Royal Challengers Bengaluru       16  1350.0          850
# 4        H Klaasen          Sunrisers Hyderabad       15  1248.0          826
#
#    fours  sixes  dismissals  highest    avg      sr  50s  100s
# 0    126    144          32    206.0  48.50  225.58    6     6
# 1    148     66          32    208.0  45.75  155.08    4     7
# 2    150     60          32    200.0  45.12  150.10    0     9
# 3    146     50          24    210.0  56.25  158.82    5     6
# 4     96     62          26    138.0  48.00  151.09    6     6

# %%
bowling_stats.head()
# Out:
#         bowler  matches  balls  runs_given  wickets  overs  economy    avg  \
# 0     K Rabada       17    800      1262.0       58  133.2     9.46  21.76
# 1      B Kumar       16    782      1008.0       56  130.2     7.73  18.00
# 2    JC Archer       16    758      1132.0       50  126.2     8.96  22.64
# 3     A Kamboj       14    630      1070.0       42  105.0    10.19  25.48
# 4  Rashid Khan       17    696      1054.0       42  116.0     9.09  25.10
#
#       sr
# 0  13.79
# 1  13.96
# 2  15.16
# 3  15.00
# 4  16.57

# %%
from google.colab import sheets
sheet = sheets.InteractiveSheet(df=bowling_stats)
# Out:
# https://docs.google.com/spreadsheets/d/1jdHQ14fBdAmuTj_goU9KeQwV-ZzxWql2xvwDKtUQWoI/edit#gid=0
#         <iframe
#             width="100%"
#             height="600"
#             src="https://docs.google.com/spreadsheets/d/1jdHQ14fBdAmuTj_goU9KeQwV-ZzxWql2xvwDKtUQWoI/edit?rm=embedded#gid=0"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
delivery.head()
# Out:
#    match_id  season        date                             venue  inning  \
# 0   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
# 1   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
# 2   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
# 3   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
# 4   1527674    2026  2026-03-28  M Chinnaswamy Stadium, Bengaluru     1.0
#
#    over_ball  over_ball2         batting_team                 bowling_team  \
# 0        0.1         0.1  Sunrisers Hyderabad  Royal Challengers Bengaluru
# 1        0.2         0.2  Sunrisers Hyderabad  Royal Challengers Bengaluru
# 2        0.3         0.3  Sunrisers Hyderabad  Royal Challengers Bengaluru
# 3        0.4         0.4  Sunrisers Hyderabad  Royal Challengers Bengaluru
# 4        0.5         0.5  Sunrisers Hyderabad  Royal Challengers Bengaluru
#
# ...

# %%
matches.columns
# Out:
# Index(['season', 'date', 'match_id', 'venue', 'city', 'toss_winner',
#        'toss_decision', 'player_of_match', 'winner', 'team1', 'team2',
#        'win_by_runs', 'win_by_wickets'],
#       dtype='object')

# %%
batting_stats.columns
# Out:
# Index(['batter', 'batting_team', 'innings', 'runs', 'balls_faced', 'fours',
#        'sixes', 'dismissals', 'highest', 'avg', 'sr', '50s', '100s'],
#       dtype='object')

# %%
delivery.columns
# Out:
# Index(['match_id', 'season', 'date', 'venue', 'inning', 'over_ball',
#        'over_ball2', 'batting_team', 'bowling_team', 'batter', 'non_striker',
#        'bowler', 'runs_batter', 'runs_extras', 'extras_detail', 'c1', 'c2',
#        'c3', 'c4', 'c5', 'wicket_kind', 'player_dismissed', 'c8', 'c9', 'c10',
#        'c11', 'c12', 'over', 'ball_num', 'runs_total', 'is_wicket'],
#       dtype='object')

# %%
points_table.columns
# Out:
# Index(['pos', 'team', 'played', 'won', 'lost', 'no_result', 'points'], dtype='object')

# %%
bowling_stats.columns
# Out:
# Index(['bowler', 'matches', 'balls', 'runs_given', 'wickets', 'overs',
#        'economy', 'avg', 'sr'],
#       dtype='object')

# %%
np.std(batting_stats['runs'])
# Out:
# 366.70379820753794

# %%
np.mean(batting_stats['runs'])
# Out:
# np.float64(297.22727272727275)

# %%
np.median(batting_stats['runs'])
# Out:
# np.float64(123.0)

# %%
print("Matches:", matches.shape)
print("Batting:", batting_stats.shape)
print("Bowling:", bowling_stats.shape)
print("Deliveries:", delivery.shape)
print("Points Table:", points_table.shape)
# Out:
# Matches: (74, 13)
# Batting: (176, 13)
# Bowling: (125, 9)
# Deliveries: (35054, 31)
# Points Table: (10, 7)

# %%
print("Matches:", matches.isnull().sum().sum())
print("Batting:", batting_stats.isnull().sum().sum())
print("Bowling:", bowling_stats.isnull().sum().sum())
print("Deliveries:", delivery.isnull().sum().sum())
print("Points:", points_table.isnull().sum().sum())
# Out:
# Matches: 3
# Batting: 28
# Bowling: 42
# Deliveries: 448532
# Points: 0

# %%
delivery.isnull().sum().sort_values(ascending=False)
# Out:
# c12                 35054
# c8                  35054
# c4                  35054
# c9                  35054
# c5                  35052
# c11                 35018
# c2                  34966
# c1                  34928
# c3                  34672
# c10                 33638
# extras_detail       33462
# wicket_kind         33290
# player_dismissed    33290
# season                  0
# match_id                0
# runs_extras             0
# runs_batter             0
# bowler                  0
# non_striker             0
# bowling_team            0
# batter                  0
# batting_team            0
# over_ball2              0
# date                    0
# over_ball               0
# inning                  0
# venue                   0
# over                    0
# ball_num                0
# runs_total              0
# is_wicket               0
# dtype: int64

# %%
delivery.drop(
    columns=['c1','c2','c3','c4','c5',
             'c8','c9','c10','c11','c12'],
    inplace=True
)

# %%
delivery['extras_detail'] = (
    delivery['extras_detail']
    .fillna('No Extra')
)

# %%
batting_stats.fillna(0, inplace=True)

# %%
bowling_stats.isnull().sum()
# Out:
# bowler         0
# matches        0
# balls          0
# runs_given     0
# wickets        0
# overs          0
# economy        0
# avg           21
# sr            21
# dtype: int64

# %%
bowling_stats.fillna(0, inplace=True)

# %%
matches.fillna("Unknown", inplace=True)

# %%
print("Matches:", matches.isnull().sum().sum())
print("Batting:", batting_stats.isnull().sum().sum())
print("Bowling:", bowling_stats.isnull().sum().sum())
print("Deliveries:", delivery.isnull().sum().sum())
print("Points:", points_table.isnull().sum().sum())
# Out:
# Matches: 0
# Batting: 0
# Bowling: 0
# Deliveries: 66580
# Points: 0

# %%
matches.to_csv('matches_clean.csv', index=False)
batting_stats.to_csv('batting_clean.csv', index=False)
bowling_stats.to_csv('bowling_clean.csv', index=False)
delivery.to_csv('deliveries_clean.csv', index=False)
points_table.to_csv('points_clean.csv', index=False)

# %%
team_wins=matches['winner'].value_counts()
print(team_wins.head(10))
# Out:
# winner
# Royal Challengers Bengaluru    11
# Gujarat Titans                 10
# Rajasthan Royals                9
# Sunrisers Hyderabad             9
# Delhi Capitals                  7
# Punjab Kings                    7
# Chennai Super Kings             6
# Kolkata Knight Riders           5
# Mumbai Indians                  4
# Lucknow Super Giants            4
# Name: count, dtype: int64

# %%
team_wins.head(10).plot(
    kind='bar',
    figsize=(10,5)

)
plt.title('Top 10 Teams by Wins')
plt.xlabel('Teams')
plt.ylabel('Wins')
plt.show()

# %%
matches['toss_match_win']=(
    matches['toss_winner']==matches['winner']
)

# %%
matches['toss_match_win'].value_counts()
# Out:
# toss_match_win
# True     37
# False    37
# Name: count, dtype: int64

# %%
matches['toss_match_win'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%'
)
plt.title("Impact of Toss on match result")
plt.ylabel('')
plt.show()

# %%
pom=matches['player_of_match'].value_counts()
print(pom.head(10))
# Out:
# player_of_match
# V Suryavanshi    3
# SV Samson        3
# V Kohli          3
# Ishan Kishan     3
# Rashid Khan      2
# Priyansh Arya    2
# SS Iyer          2
# Tilak Varma      2
# KL Rahul         2
# K Rabada         2
# Name: count, dtype: int64

# %%
pom.head(10).plot(
    kind='bar',
    figsize=(10,5)
)
plt.title("Top 10 Player of the Match Winners")
plt.xlabel("Name of the player")
plt.ylabel("POM")
plt.show()

# %%
venue_matches=matches['venue'].value_counts()
print(venue_matches.head())
# Out:
# venue
# Narendra Modi Stadium, Ahmedabad                                         8
# Bharat Ratna Shri Atal Bihari Vajpayee Ekana Cricket Stadium, Lucknow    7
# MA Chidambaram Stadium, Chepauk, Chennai                                 7
# Eden Gardens, Kolkata                                                    7
# Wankhede Stadium, Mumbai                                                 7
# Name: count, dtype: int64

# %%
venue_matches=matches['venue'].value_counts()
print(venue_matches.head(20).reset_index())
# Out:
#                                                 venue  count
# 0                    Narendra Modi Stadium, Ahmedabad      8
# 1   Bharat Ratna Shri Atal Bihari Vajpayee Ekana C...      7
# 2            MA Chidambaram Stadium, Chepauk, Chennai      7
# 3                               Eden Gardens, Kolkata      7
# 4                            Wankhede Stadium, Mumbai      7
# 5   Rajiv Gandhi International Stadium, Uppal, Hyd...      7
# 6                         Arun Jaitley Stadium, Delhi      7
# 7   Maharaja Yadavindra Singh International Cricke...      6
# 8                    M Chinnaswamy Stadium, Bengaluru      5
# 9   Himachal Pradesh Cricket Association Stadium, ...      4
# 10                     Sawai Mansingh Stadium, Jaipur      4
# 11                Barsapara Cricket Stadium, Guwahati      3
# 12  Shaheed Veer Narayan Singh International Stadi...      2

# %%
venue_matches.head(10).plot(
    kind='bar',
    figsize=(10,5)

)
plt.title("Top venues by matches")
plt.xlabel("venue")
plt.ylabel("Matches")
plt.show()

# %%
season_matches=matches['season'].value_counts()
print(season_matches)
# Out:
# season
# 2026    74
# Name: count, dtype: int64
